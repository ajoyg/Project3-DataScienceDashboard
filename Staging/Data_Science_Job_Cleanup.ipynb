# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from geopy.geocoders import Nominatim

# %%
ds_jobs_raw_df = pd.read_csv('../Resources/Cleaned_DS_Jobs.csv')
ds_jobs_raw_df
# Out:
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 655     Data Scientist        105-167
# 656     Data Scientist        105-167
# 657     Data Scientist        105-167
# 658     Data Scientist        105-167
# 659     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 655              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 656                  JKGT  San Francisco, CA                      -1
# 657            AccessHope      Irwindale, CA                      -1
# 658  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 659         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 655   1001 to 5000 employees        Company - Private
# 656                       -1                       -1
# 657                       -1                       -1
# 658        1 to 50 employees        Company - Private
# 659   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... company_age python  excel  \
# 0                       Insurance Carriers  ...          27      0      0
# 1                   Research & Development  ...          52      0      0
# 2                               Consulting  ...          39      1      1
# 3    Electrical & Electronic Manufacturing  ...          20      1      1
# 4                  Advertising & Marketing  ...          22      1      1
# ..                                     ...  ...         ...    ...    ...
# 655                Advertising & Marketing  ...          31      1      1
# 656                                     -1  ...          -1      0      0
# 657                                     -1  ...          -1      1      1
# 658                Advertising & Marketing  ...          -1      1      0
# 659                              Wholesale  ...          44      1      1
#
#      hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0         0      0   1        0         0  data scientist     senior
# 1         1      0   0        0         1  data scientist         na
# 2         0      0   1        0         0  data scientist         na
# 3         0      0   1        0         0  data scientist         na
# 4         0      0   0        0         0  data scientist         na
# ..      ...    ...  ..      ...       ...             ...        ...
# 655       1      0   0        1         1  data scientist         na
# 656       0      0   0        0         0  data scientist         na
# 657       1      0   0        1         0  data scientist         na
# 658       1      1   0        0         1  data scientist         na
# 659       0      0   0        1         0  data scientist         na
#
# [660 rows x 27 columns]

# %%
geolocator = Nominatim(timeout=5, user_agent="geocoder")  
ds_jobs_raw_df['geocode'] = ds_jobs_raw_df.loc[:,"Location"].apply(geolocator.geocode)
ds_jobs_raw_df
# Out:
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 655     Data Scientist        105-167
# 656     Data Scientist        105-167
# 657     Data Scientist        105-167
# 658     Data Scientist        105-167
# 659     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 655              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 656                  JKGT  San Francisco, CA                      -1
# 657            AccessHope      Irwindale, CA                      -1
# 658  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 659         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 655   1001 to 5000 employees        Company - Private
# 656                       -1                       -1
# 657                       -1                       -1
# 658        1 to 50 employees        Company - Private
# 659   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... python excel  hadoop  spark  \
# 0                       Insurance Carriers  ...      0     0       0      0
# 1                   Research & Development  ...      0     0       1      0
# 2                               Consulting  ...      1     1       0      0
# 3    Electrical & Electronic Manufacturing  ...      1     1       0      0
# 4                  Advertising & Marketing  ...      1     1       0      0
# ..                                     ...  ...    ...   ...     ...    ...
# 655                Advertising & Marketing  ...      1     1       1      0
# 656                                     -1  ...      0     0       0      0
# 657                                     -1  ...      1     1       1      0
# 658                Advertising & Marketing  ...      1     0       1      1
# 659                              Wholesale  ...      1     1       0      0
#
#      aws tableau  big_data        job_simp  seniority  \
# 0      1       0         0  data scientist     senior
# 1      0       0         1  data scientist         na
# 2      1       0         0  data scientist         na
# 3      1       0         0  data scientist         na
# 4      0       0         0  data scientist         na
# ..   ...     ...       ...             ...        ...
# 655    0       1         1  data scientist         na
# 656    0       0         0  data scientist         na
# 657    0       1         0  data scientist         na
# 658    0       0         1  data scientist         na
# 659    0       1         0  data scientist         na
#
#                                                geocode
# 0    (City of New York, New York, United States, (4...
# 1    (Chantilly, Fairfax County, Virginia, United S...
# 2    (Boston, Suffolk County, Massachusetts, United...
# 3    (Newton, Middlesex County, Massachusetts, Unit...
# 4    (City of New York, New York, United States, (4...
# ..                                                 ...
# 655  (Fort Lee, Bergen County, New Jersey, 07024, U...
# 656  (San Francisco, CAL Fire Northern Region, Cali...
# 657  (Irwindale, Los Angeles County, CAL Fire Contr...
# 658  (San Francisco, CAL Fire Northern Region, Cali...
# 659  (City of New York, New York, United States, (4...
#
# [660 rows x 28 columns]

# %%
ds_jobs_raw_df["latitude"] = [g.latitude for g in ds_jobs_raw_df.geocode]
ds_jobs_raw_df["longitude"] = [g.longitude for g in ds_jobs_raw_df.geocode]
ds_jobs_raw_df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
#                       Size        Type of ownership  \
# 0   1001 to 5000 employees   Nonprofit Organization
# 1  5001 to 10000 employees         Company - Public
# 2   1001 to 5000 employees  Private Practice / Firm
# 3    501 to 1000 employees         Company - Public
# 4      51 to 200 employees        Company - Private
#
#                                 Industry  ... hadoop spark  aws  tableau  \
# 0                     Insurance Carriers  ...      0     0    1        0
# 1                 Research & Development  ...      1     0    0        0
# 2                             Consulting  ...      0     0    1        0
# 3  Electrical & Electronic Manufacturing  ...      0     0    1        0
# 4                Advertising & Marketing  ...      0     0    0        0
#
#    big_data        job_simp  seniority  \
# 0         0  data scientist     senior
# 1         1  data scientist         na
# 2         0  data scientist         na
# 3         0  data scientist         na
# 4         0  data scientist         na
#
#                                              geocode   latitude  longitude
# 0  (City of New York, New York, United States, (4...  40.712728 -74.006015
# 1  (Chantilly, Fairfax County, Virginia, United S...  38.878836 -77.402217
# 2  (Boston, Suffolk County, Massachusetts, United...  42.355433 -71.060511
# 3  (Newton, Middlesex County, Massachusetts, Unit...  42.337041 -71.209221
# 4  (City of New York, New York, United States, (4...  40.712728 -74.006015
#
# [5 rows x 30 columns]

# %%
ds_jobs_raw_df['Sector'] = ds_jobs_raw_df['Sector'].str.replace('- ', '_')
ds_jobs_raw_df['Sector'].head(50)
# Out:
# 0                      Insurance
# 1              Business Services
# 2              Business Services
# 3                  Manufacturing
# 4              Business Services
# 5         Information Technology
# 6      Biotech & Pharmaceuticals
# 7                         Retail
# 8         Information Technology
# 9         Information Technology
# 10        Information Technology
# 11        Information Technology
# 12    Oil_Gas_Energy & Utilities
# 13                 Manufacturing
# 14             Business Services
# 15                    Government
# 16                 Manufacturing
# 17        Information Technology
# 18                   Health Care
# 19        Information Technology
# 20        Information Technology
# 21             Business Services
# 22                     Insurance
# 23             Business Services
# 24        Information Technology
# 25                       Finance
# 26           Aerospace & Defense
# 27                    Government
# 28        Information Technology
# 29             Business Services
# 30     Biotech & Pharmaceuticals
# 31        Information Technology
# 32                     Insurance
# 33        Information Technology
# 34    Oil_Gas_Energy & Utilities
# 35        Information Technology
# 36                   Health Care
# 37        Information Technology
# 38        Information Technology
# 39                       Finance
# 40                     Insurance
# 41                            -1
# 42     Biotech & Pharmaceuticals
# 43        Information Technology
# 44     Biotech & Pharmaceuticals
# 45        Information Technology
# 46                       Finance
# 47                    Government
# 48        Information Technology
# 49             Business Services
# Name: Sector, dtype: object

# %%
values_to_drop=['United States', 'Patuxent, Anne Arundel, MD']
ds_jobs_all_city = ds_jobs_raw_df.loc[~ds_jobs_raw_df['Location'].isin(values_to_drop)]
ds_jobs_all_city.head(50)
ds_jobs_all_city[['city', 'state']] = ds_jobs_all_city['Location'].str.split(',', expand=True)
ds_jobs_all_city
# Out:
# c:\Users\ajayg\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#              Job Title Salary Estimate  \
# 0    Sr Data Scientist        137-171
# 1       Data Scientist        137-171
# 2       Data Scientist        137-171
# 3       Data Scientist        137-171
# 4       Data Scientist        137-171
# ..                 ...             ...
# 655     Data Scientist        105-167
# 656     Data Scientist        105-167
# 657     Data Scientist        105-167
# 658     Data Scientist        105-167
# 659     Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location            Headquarters  \
# 0             Healthfirst       New York, NY            New York, NY
# 1                 ManTech      Chantilly, VA             Herndon, VA
# 2          Analysis Group         Boston, MA              Boston, MA
# 3                 INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions       New York, NY            New York, NY
# ..                    ...                ...                     ...
# 655              TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 656                  JKGT  San Francisco, CA                      -1
# 657            AccessHope      Irwindale, CA                      -1
# 658  ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 659         1-800-Flowers       New York, NY         Carle Place, NY
#
#                         Size        Type of ownership  \
# 0     1001 to 5000 employees   Nonprofit Organization
# 1    5001 to 10000 employees         Company - Public
# 2     1001 to 5000 employees  Private Practice / Firm
# 3      501 to 1000 employees         Company - Public
# 4        51 to 200 employees        Company - Private
# ..                       ...                      ...
# 655   1001 to 5000 employees        Company - Private
# 656                       -1                       -1
# 657                       -1                       -1
# 658        1 to 50 employees        Company - Private
# 659   1001 to 5000 employees         Company - Public
#
#                                   Industry  ... aws tableau  big_data  \
# 0                       Insurance Carriers  ...   1       0         0
# 1                   Research & Development  ...   0       0         1
# 2                               Consulting  ...   1       0         0
# 3    Electrical & Electronic Manufacturing  ...   1       0         0
# 4                  Advertising & Marketing  ...   0       0         0
# ..                                     ...  ...  ..     ...       ...
# 655                Advertising & Marketing  ...   0       1         1
# 656                                     -1  ...   0       0         0
# 657                                     -1  ...   0       1         0
# 658                Advertising & Marketing  ...   0       0         1
# 659                              Wholesale  ...   0       1         0
#
#            job_simp  seniority  \
# 0    data scientist     senior
# 1    data scientist         na
# 2    data scientist         na
# 3    data scientist         na
# 4    data scientist         na
# ..              ...        ...
# 655  data scientist         na
# 656  data scientist         na
# 657  data scientist         na
# 658  data scientist         na
# 659  data scientist         na
#
#                                                geocode   latitude   longitude  \
# 0    (City of New York, New York, United States, (4...  40.712728  -74.006015
# 1    (Chantilly, Fairfax County, Virginia, United S...  38.878836  -77.402217
# 2    (Boston, Suffolk County, Massachusetts, United...  42.355433  -71.060511
# 3    (Newton, Middlesex County, Massachusetts, Unit...  42.337041  -71.209221
# 4    (City of New York, New York, United States, (4...  40.712728  -74.006015
# ..                                                 ...        ...         ...
# 655  (Fort Lee, Bergen County, New Jersey, 07024, U...  40.850933  -73.970138
# 656  (San Francisco, CAL Fire Northern Region, Cali...  37.779026 -122.419906
# 657  (Irwindale, Los Angeles County, CAL Fire Contr...  34.106993 -117.934214
# 658  (San Francisco, CAL Fire Northern Region, Cali...  37.779026 -122.419906
# 659  (City of New York, New York, United States, (4...  40.712728  -74.006015
#
#               city  state
# 0         New York     NY
# 1        Chantilly     VA
# 2           Boston     MA
# 3           Newton     MA
# 4         New York     NY
# ..             ...    ...
# 655       Fort Lee     NJ
# 656  San Francisco     CA
# 657      Irwindale     CA
# 658  San Francisco     CA
# 659       New York     NY
#
# [648 rows x 32 columns]

# %%
ds_jobs_all_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 648 entries, 0 to 659
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          648 non-null    object
#  1   Salary Estimate    648 non-null    object
#  2   Job Description    648 non-null    object
#  3   Rating             648 non-null    float64
#  4   Company Name       648 non-null    object
#  5   Location           648 non-null    object
#  6   Headquarters       648 non-null    object
#  7   Size               648 non-null    object
#  8   Type of ownership  648 non-null    object
#  9   Industry           648 non-null    object
#  10  Sector             648 non-null    object
#  11  Revenue            648 non-null    object
#  12  min_salary         648 non-null    int64
#  13  max_salary         648 non-null    int64
#  14  avg_salary         648 non-null    int64
#  15  job_state          648 non-null    object
#  16  same_state         648 non-null    int64
#  17  company_age        648 non-null    int64
#  18  python             648 non-null    int64
#  19  excel              648 non-null    int64
#  20  hadoop             648 non-null    int64
#  21  spark              648 non-null    int64
#  22  aws                648 non-null    int64
#  23  tableau            648 non-null    int64
#  24  big_data           648 non-null    int64
#  25  job_simp           648 non-null    object
#  26  seniority          648 non-null    object
#  27  geocode            648 non-null    object
#  28  latitude           648 non-null    float64
#  29  longitude          648 non-null    float64
#  30  city               648 non-null    object
#  31  state              648 non-null    object
# dtypes: float64(3), int64(12), object(17)
# memory usage: 167.1+ KB

# %%
df_jobs_cleaned = ds_jobs_all_city.drop(["geocode","Headquarters"], axis=1)
df_jobs_cleaned = df_jobs_cleaned.rename(columns= {"Job Title": "job_title","Salary Estimate": "salary_estimate","Job Description": "job_description","Rating": "rating",\
                                                   "Company Name": "company_name","Location": "location", "Headquarters": "headquarters", "Size": "size","Type of ownership": "type_of_ownership",\
                                                    "Industry": "industry", "Sector": "sector", "Revenue": "revenue"})
df_jobs_cleaned = df_jobs_cleaned[['job_title','salary_estimate','rating','company_name','city','state','latitude','longitude',\
                                   'size','type_of_ownership','industry','sector','revenue','min_salary','max_salary','avg_salary','job_state','same_state','company_age',\
                                    'python','excel','hadoop','spark','aws','tableau','big_data','job_simp','seniority']]

df_jobs_cleaned
# Out:
#              job_title salary_estimate  rating          company_name  \
# 0    Sr Data Scientist        137-171      3.1           Healthfirst
# 1       Data Scientist        137-171      4.2               ManTech
# 2       Data Scientist        137-171      3.8        Analysis Group
# 3       Data Scientist        137-171      3.5               INFICON
# 4       Data Scientist        137-171      2.9    Affinity Solutions
# ..                 ...             ...     ...                   ...
# 655     Data Scientist        105-167      3.6              TRANZACT
# 656     Data Scientist        105-167      0.0                  JKGT
# 657     Data Scientist        105-167      0.0            AccessHope
# 658     Data Scientist        105-167      5.0  ChaTeck Incorporated
# 659     Data Scientist        105-167      2.7         1-800-Flowers
#
#               city state   latitude   longitude                     size  \
# 0         New York    NY  40.712728  -74.006015   1001 to 5000 employees
# 1        Chantilly    VA  38.878836  -77.402217  5001 to 10000 employees
# 2           Boston    MA  42.355433  -71.060511   1001 to 5000 employees
# 3           Newton    MA  42.337041  -71.209221    501 to 1000 employees
# 4         New York    NY  40.712728  -74.006015      51 to 200 employees
# ..             ...   ...        ...         ...                      ...
# 655       Fort Lee    NJ  40.850933  -73.970138   1001 to 5000 employees
# 656  San Francisco    CA  37.779026 -122.419906                       -1
# 657      Irwindale    CA  34.106993 -117.934214                       -1
# 658  San Francisco    CA  37.779026 -122.419906        1 to 50 employees
# 659       New York    NY  40.712728  -74.006015   1001 to 5000 employees
#
#            type_of_ownership  ... company_age python excel  hadoop  spark  \
# 0     Nonprofit Organization  ...          27      0     0       0      0
# 1           Company - Public  ...          52      0     0       1      0
# 2    Private Practice / Firm  ...          39      1     1       0      0
# 3           Company - Public  ...          20      1     1       0      0
# 4          Company - Private  ...          22      1     1       0      0
# ..                       ...  ...         ...    ...   ...     ...    ...
# 655        Company - Private  ...          31      1     1       1      0
# 656                       -1  ...          -1      0     0       0      0
# 657                       -1  ...          -1      1     1       1      0
# 658        Company - Private  ...          -1      1     0       1      1
# 659         Company - Public  ...          44      1     1       0      0
#
#      aws tableau  big_data        job_simp  seniority
# 0      1       0         0  data scientist     senior
# 1      0       0         1  data scientist         na
# 2      1       0         0  data scientist         na
# 3      1       0         0  data scientist         na
# 4      0       0         0  data scientist         na
# ..   ...     ...       ...             ...        ...
# 655    0       1         1  data scientist         na
# 656    0       0         0  data scientist         na
# 657    0       1         0  data scientist         na
# 658    0       0         1  data scientist         na
# 659    0       1         0  data scientist         na
#
# [648 rows x 28 columns]

# %%
#Get the Salaries data
df_salaries_raw = pd.read_csv("../Resources/ds_salaries.csv")
df_salaries_raw
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %%
df_salaries_cleaned = df_salaries_raw[['work_year', 'experience_level','employment_type','job_title','salary','salary_currency', 'salary_in_usd','employee_residence','remote_ratio','company_location','company_size']]
df_salaries_cleaned
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR          79833                 DE             0
# 1    260000             USD         260000                 JP             0
# 2     85000             GBP         109024                 GB            50
# 3     20000             USD          20000                 HN             0
# 4    150000             USD         150000                 US            50
# ..      ...             ...            ...                ...           ...
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 3                 HN            S
# 4                 US            L
# ..               ...          ...
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L
#
# [607 rows x 11 columns]

# %%
geolocator = Nominatim(timeout=5, user_agent="geocoder")  
df_salaries_cleaned['company_location'].unique()
df_salaries_raw['geocode'] = df_salaries_raw.loc[:,"company_location"].apply(geolocator.geocode)
df_salaries_raw
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size  \
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
#                                         geocode
# 0       (Deutschland, (51.1638175, 10.4478313))
# 1               (日本, (36.5748441, 139.2394179))
# 2    (United Kingdom, (54.7023545, -3.2765753))
# 3         (Honduras, (15.2572432, -86.0755145))
# 4    (United States, (39.7837304, -100.445882))
# ..                                          ...
# 602  (United States, (39.7837304, -100.445882))
# 603  (United States, (39.7837304, -100.445882))
# 604  (United States, (39.7837304, -100.445882))
# 605  (United States, (39.7837304, -100.445882))
# 606  (United States, (39.7837304, -100.445882))
#
# [607 rows x 13 columns]

# %%
df_salaries_raw["latitude"] = [g.latitude for g in df_salaries_raw.geocode]
df_salaries_raw["longitude"] = [g.longitude for g in df_salaries_raw.geocode]
df_salaries_raw
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size  \
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
#                                         geocode   latitude   longitude
# 0       (Deutschland, (51.1638175, 10.4478313))  51.163818   10.447831
# 1               (日本, (36.5748441, 139.2394179))  36.574844  139.239418
# 2    (United Kingdom, (54.7023545, -3.2765753))  54.702354   -3.276575
# 3         (Honduras, (15.2572432, -86.0755145))  15.257243  -86.075514
# 4    (United States, (39.7837304, -100.445882))  39.783730 -100.445882
# ..                                          ...        ...         ...
# 602  (United States, (39.7837304, -100.445882))  39.783730 -100.445882
# 603  (United States, (39.7837304, -100.445882))  39.783730 -100.445882
# 604  (United States, (39.7837304, -100.445882))  39.783730 -100.445882
# 605  (United States, (39.7837304, -100.445882))  39.783730 -100.445882
# 606  (United States, (39.7837304, -100.445882))  39.783730 -100.445882
#
# [607 rows x 15 columns]

# %%
df_salaries_cleaned = df_salaries_raw.drop(columns=['Unnamed: 0', 'geocode'])
df_salaries_cleaned = df_salaries_cleaned[['work_year', 'experience_level','employment_type','job_title','salary','salary_currency', 'salary_in_usd','employee_residence','remote_ratio','company_location','latitude','longitude','company_size']]
df_salaries_cleaned
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR          79833                 DE             0
# 1    260000             USD         260000                 JP             0
# 2     85000             GBP         109024                 GB            50
# 3     20000             USD          20000                 HN             0
# 4    150000             USD         150000                 US            50
# ..      ...             ...            ...                ...           ...
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location   latitude   longitude company_size
# 0                 DE  51.163818   10.447831            L
# 1                 JP  36.574844  139.239418            S
# 2                 GB  54.702354   -3.276575            M
# 3                 HN  15.257243  -86.075514            S
# 4                 US  39.783730 -100.445882            L
# ..               ...        ...         ...          ...
# 602               US  39.783730 -100.445882            M
# 603               US  39.783730 -100.445882            M
# 604               US  39.783730 -100.445882            M
# 605               US  39.783730 -100.445882            M
# 606               US  39.783730 -100.445882            L
#
# [607 rows x 13 columns]

# %%
# Save the cleaned files a a csv into the Staging folder
df_jobs_cleaned.to_csv("data/jobs_cleaned.csv", index=False)
df_salaries_cleaned.to_csv("data/salaries_cleaned.csv", index=False)

# %%
df_salaries_cleaned.to_json("data/salaries.json")
